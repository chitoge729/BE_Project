# %% [markdown]
# <a href="https://colab.research.google.com/github/chitoge729/BE_Project/blob/main/BE_Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.0.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.11.3)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("https://raw.githubusercontent.com/chitoge729/Dataset/main/all_fuels_data_2023.csv")

# %%
df.head()
# Out:
#   ticker  commodity        date       open       high        low      close  \
# 0   CL=F  Crude Oil  2000-08-23  31.950001  32.799999  31.950001  32.049999
# 1   CL=F  Crude Oil  2000-08-24  31.900000  32.240002  31.400000  31.629999
# 2   CL=F  Crude Oil  2000-08-25  31.700001  32.099998  31.320000  32.049999
# 3   CL=F  Crude Oil  2000-08-28  32.040001  32.919998  31.860001  32.869999
# 4   CL=F  Crude Oil  2000-08-29  32.820000  33.029999  32.560001  32.720001
#
#    volume
# 0   79385
# 1   72978
# 2   44601
# 3   46770
# 4   49131

# %%
df.tail()
# Out:
#       ticker        commodity        date       open       high        low  \
# 27295   BZ=F  Brent Crude Oil  2023-11-03  86.860001  87.779999  84.550003
# 27296   BZ=F  Brent Crude Oil  2023-11-06  85.389999  86.449997  84.910004
# 27297   BZ=F  Brent Crude Oil  2023-11-07  85.230003  85.320000  81.419998
# 27298   BZ=F  Brent Crude Oil  2023-11-08  81.470001  81.930000  79.160004
# 27299   BZ=F  Brent Crude Oil  2023-11-09  79.699997  80.669998  79.610001
#
#            close  volume
# 27295  84.889999   36172
# 27296  85.180000   26524
# 27297  81.610001   38007
# 27298  79.540001   36137
# 27299  80.559998    1009

# %%
df.isnull().sum()
# Out:
# ticker       0
# commodity    0
# date         0
# open         0
# high         0
# low          0
# close        0
# volume       0
# dtype: int64

# %%
df.shape
# Out:
# (27300, 8)

# %%
df.describe()
# Out:
#                open          high           low         close        volume
# count  27300.000000  27300.000000  27300.000000  27300.000000  2.730000e+04
# mean      27.113506     27.503700     26.698357     27.111346  1.056756e+05
# std       36.011099     36.465119     35.523887     36.013934  1.492724e+05
# min      -14.000000      0.507000    -40.320000    -37.630001  0.000000e+00
# 25%        2.013000      2.044000      1.981000      2.014275  2.617900e+04
# 50%        3.420500      3.500000      3.341000      3.419000  4.867900e+04
# 75%       53.759998     54.602499     52.865001     53.799999  1.131625e+05
# max      146.080002    147.429993    144.270004    146.080002  2.288230e+06

# %%
df.boxplot('volume')
# Out:
# <Axes: >

# %%
Q1 = df['volume'].quantile(0.25)
Q3 = df['volume'].quantile(0.75)

IQR = Q3 - Q1

LL = Q1 - 1.5*IQR
UL = Q3 + 1.5*IQR

outliers = df[(df['volume']<LL) | (df['volume'])>UL]
df_filtered = df[(df['volume'] >= LL) & (df['volume'] <= UL)]

# %%
df_filtered.boxplot('volume')
# Out:
# <Axes: >

# %%
SC = StandardScaler()

df_1 = df_filtered[['volume', 'open', 'high', 'low', 'close']]
df_2 = SC.fit_transform(df_1)

# %%
numeric_columns = df_filtered.select_dtypes(include=['number'])

# %%
df_standardized = df_filtered.copy()

# %%
df_standardized[numeric_columns.columns] = SC.fit_transform(numeric_columns)

# %%
df_standardized
# Out:
#       ticker        commodity        date      open      high       low  \
# 0       CL=F        Crude Oil  2000-08-23  0.319895  0.333081  0.332685
# 1       CL=F        Crude Oil  2000-08-24  0.318396  0.316484  0.316003
# 2       CL=F        Crude Oil  2000-08-25  0.312401  0.312334  0.313576
# 3       CL=F        Crude Oil  2000-08-28  0.322592  0.336637  0.329955
# 4       CL=F        Crude Oil  2000-08-29  0.345972  0.339898  0.351188
# ...      ...              ...         ...       ...       ...       ...
# 27295   BZ=F  Brent Crude Oil  2023-11-03  1.965728  1.962573  1.928149
# 27296   BZ=F  Brent Crude Oil  2023-11-06  1.921667  1.923154  1.939068
# 27297   BZ=F  Brent Crude Oil  2023-11-07  1.916872  1.889664  1.833209
# 27298   BZ=F  Brent Crude Oil  2023-11-08  1.804172  1.789191  1.764659
# 27299   BZ=F  Brent Crude Oil  2023-11-09  1.751119  1.751847  1.778309
#
#           close    volume
# 0      0.322660  0.401745
# 1      0.310076  0.278476
# 2      0.322660 -0.267493
# 3      0.347230 -0.225762
# 4      0.342736 -0.180337
# ...         ...       ...
# 27295  1.905907 -0.429666
# 27296  1.914596 -0.615292
# 27297  1.807628 -0.394361
# 27298  1.745604 -0.430339
# 27299  1.776167 -1.106197
#
# [23899 rows x 8 columns]

# %%
sns.histplot(df_standardized['volume'], bins=10, kde=True)
# Out:
# <Axes: xlabel='volume', ylabel='Count'>

# %%
sns.histplot(df_standardized['open'], bins=10, kde=True)
# Out:
# <Axes: xlabel='open', ylabel='Count'>

# %%
sns.histplot(df_standardized['high'], bins=10, kde=True)
# Out:
# <Axes: xlabel='high', ylabel='Count'>

# %%
sns.histplot(df_standardized['low'], bins=10, kde=True)
# Out:
# <Axes: xlabel='low', ylabel='Count'>

# %%
sns.histplot(df_standardized['close'], bins=10, kde=True)
# Out:
# <Axes: xlabel='close', ylabel='Count'>

# %%
df_standardized['date'] = pd.to_datetime(df_standardized['date'])

df_standardized['DayOfWeek'] = df_standardized['date'].dt.dayofweek
df_standardized['Month'] = df_standardized['date'].dt.month
df_standardized['Year'] = df_standardized['date'].dt.year

# %%
df_standardized
# Out:
#       ticker        commodity       date      open      high       low  \
# 0       CL=F        Crude Oil 2000-08-23  0.319895  0.333081  0.332685
# 1       CL=F        Crude Oil 2000-08-24  0.318396  0.316484  0.316003
# 2       CL=F        Crude Oil 2000-08-25  0.312401  0.312334  0.313576
# 3       CL=F        Crude Oil 2000-08-28  0.322592  0.336637  0.329955
# 4       CL=F        Crude Oil 2000-08-29  0.345972  0.339898  0.351188
# ...      ...              ...        ...       ...       ...       ...
# 27295   BZ=F  Brent Crude Oil 2023-11-03  1.965728  1.962573  1.928149
# 27296   BZ=F  Brent Crude Oil 2023-11-06  1.921667  1.923154  1.939068
# 27297   BZ=F  Brent Crude Oil 2023-11-07  1.916872  1.889664  1.833209
# 27298   BZ=F  Brent Crude Oil 2023-11-08  1.804172  1.789191  1.764659
# 27299   BZ=F  Brent Crude Oil 2023-11-09  1.751119  1.751847  1.778309
#
#           close    volume  DayOfWeek  Month  Year
# 0      0.322660  0.401745          2      8  2000
# 1      0.310076  0.278476          3      8  2000
# 2      0.322660 -0.267493          4      8  2000
# 3      0.347230 -0.225762          0      8  2000
# 4      0.342736 -0.180337          1      8  2000
# ...         ...       ...        ...    ...   ...
# 27295  1.905907 -0.429666          4     11  2023
# 27296  1.914596 -0.615292          0     11  2023
# 27297  1.807628 -0.394361          1     11  2023
# 27298  1.745604 -0.430339          2     11  2023
# 27299  1.776167 -1.106197          3     11  2023
#
# [23899 rows x 11 columns]

# %%
label_encoder = LabelEncoder()

df_standardized['Symbol_encoded'] = label_encoder.fit_transform(df_standardized['commodity'])

# %%
correlation_matrix = df[['commodity', 'open', 'high', 'low', 'close', 'volume']].corr()

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5, square=True)

plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-25-c29c9e7e6366>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df[['commodity', 'open', 'high', 'low', 'close', 'volume']].corr()

# %%
df_standardized['commodity'].unique()
# Out:
# array(['Crude Oil', 'Heating Oil', 'Natural Gas', 'RBOB Gasoline',
#        'Brent Crude Oil'], dtype=object)

# %%
df_standardized['commodity'].value_counts()
# Out:
# Heating Oil        5822
# RBOB Gasoline      5783
# Natural Gas        5692
# Brent Crude Oil    4041
# Crude Oil          2561
# Name: commodity, dtype: int64

# %%
sequence_length = 20

def create_sequences(data, sequence_length):
    sequences = []
    for i in range(len(data) - sequence_length):
        seq = data[i:i+sequence_length]
        sequences.append(seq)
    return np.array(sequences)

def train_evaluate_xgboost(X_train, y_train, X_test, y_test):
    # Reshape X_train and X_test
    X_train_flattened = X_train.reshape((X_train.shape[0], X_train.shape[1] * X_train.shape[2]))
    X_test_flattened = X_test.reshape((X_test.shape[0], X_test.shape[1] * X_test.shape[2]))

    model = XGBRegressor(objective='reg:squarederror', n_estimators=200, max_depth=5, learning_rate=0.1, reg_alpha=0.1, reg_lambda=0.1)
    model.fit(X_train_flattened, y_train)

    # Make predictions
    predictions = model.predict(X_test_flattened)


    # Evaluate model
    mse = mean_squared_error(y_test, predictions)
    print(f'XGBoost Mean Squared Error: {mse}')

    # Plot predictions
    plt.plot(predictions, label='XGBoost Predicted')
    plt.plot(y_test, label='Actual')
    plt.legend()
    plt.show()


# Target variable: 'open'
target_variable = 'open'
target_data = df_standardized[[target_variable]]

scaler = MinMaxScaler()
target_data_scaled = scaler.fit_transform(target_data)

sequences = create_sequences(target_data_scaled, sequence_length)

train_size = int(len(sequences) * 0.8)
train_data, test_data = sequences[:train_size], sequences[train_size:]

X_train, y_train = train_data[:, :-1], train_data[:, -1]
X_test, y_test = test_data[:, :-1], test_data[:, -1]

# Train and evaluate XGBoost model for 'open'
train_evaluate_xgboost(X_train, y_train, X_test, y_test)
# Out:
# XGBoost Mean Squared Error: 0.0006828739728153308

# %%
sequence_length = 20

def create_sequences(data, sequence_length):
    sequences = []
    for i in range(len(data) - sequence_length):
        seq = data[i:i+sequence_length]
        sequences.append(seq)
    return np.array(sequences)

def train_evaluate_xgboost(X_train, y_train, X_test, y_test):
    # Reshape X_train and X_test
    X_train_flattened = X_train.reshape((X_train.shape[0], X_train.shape[1] * X_train.shape[2]))
    X_test_flattened = X_test.reshape((X_test.shape[0], X_test.shape[1] * X_test.shape[2]))

    model = XGBRegressor(objective='reg:squarederror', n_estimators=200, max_depth=5, learning_rate=0.1, reg_alpha=0.1, reg_lambda=0.1)
    model.fit(X_train_flattened, y_train)

    # Make predictions
    predictions = model.predict(X_test_flattened)


    # Evaluate model
    mse = mean_squared_error(y_test, predictions)
    print(f'XGBoost Mean Squared Error: {mse}')

    # Plot predictions
    plt.plot(predictions, label='XGBoost Predicted')
    plt.plot(y_test, label='Actual')
    plt.legend()
    plt.show()


# Target variable: 'high'
target_variable = 'high'
target_data = df_standardized[[target_variable]]

scaler = MinMaxScaler()
target_data_scaled = scaler.fit_transform(target_data)

sequences = create_sequences(target_data_scaled, sequence_length)

train_size = int(len(sequences) * 0.8)
train_data, test_data = sequences[:train_size], sequences[train_size:]

X_train, y_train = train_data[:, :-1], train_data[:, -1]
X_test, y_test = test_data[:, :-1], test_data[:, -1]

# Train and evaluate XGBoost model for 'high'
train_evaluate_xgboost(X_train, y_train, X_test, y_test)
# Out:
# XGBoost Mean Squared Error: 0.0006851997452190886

# %%
sequence_length = 20

def create_sequences(data, sequence_length):
    sequences = []
    for i in range(len(data) - sequence_length):
        seq = data[i:i+sequence_length]
        sequences.append(seq)
    return np.array(sequences)

def train_evaluate_xgboost(X_train, y_train, X_test, y_test):
    # Reshape X_train and X_test
    X_train_flattened = X_train.reshape((X_train.shape[0], X_train.shape[1] * X_train.shape[2]))
    X_test_flattened = X_test.reshape((X_test.shape[0], X_test.shape[1] * X_test.shape[2]))

    model = XGBRegressor(objective='reg:squarederror', n_estimators=200, max_depth=5, learning_rate=0.1, reg_alpha=0.1, reg_lambda=0.1)
    model.fit(X_train_flattened, y_train)

    # Make predictions
    predictions = model.predict(X_test_flattened)


    # Evaluate model
    mse = mean_squared_error(y_test, predictions)
    print(f'XGBoost Mean Squared Error: {mse}')

    # Plot predictions
    plt.plot(predictions, label='XGBoost Predicted')
    plt.plot(y_test, label='Actual')
    plt.legend()
    plt.show()


# Target variable: 'low'
target_variable = 'low'
target_data = df_standardized[[target_variable]]

scaler = MinMaxScaler()
target_data_scaled = scaler.fit_transform(target_data)

sequences = create_sequences(target_data_scaled, sequence_length)

train_size = int(len(sequences) * 0.8)
train_data, test_data = sequences[:train_size], sequences[train_size:]

X_train, y_train = train_data[:, :-1], train_data[:, -1]
X_test, y_test = test_data[:, :-1], test_data[:, -1]

# Train and evaluate XGBoost model for 'low'
train_evaluate_xgboost(X_train, y_train, X_test, y_test)
# Out:
# XGBoost Mean Squared Error: 0.0006427352871000738

# %%
sequence_length = 20

def create_sequences(data, sequence_length):
    sequences = []
    for i in range(len(data) - sequence_length):
        seq = data[i:i+sequence_length]
        sequences.append(seq)
    return np.array(sequences)

def train_evaluate_xgboost(X_train, y_train, X_test, y_test):
    # Reshape X_train and X_test
    X_train_flattened = X_train.reshape((X_train.shape[0], X_train.shape[1] * X_train.shape[2]))
    X_test_flattened = X_test.reshape((X_test.shape[0], X_test.shape[1] * X_test.shape[2]))

    model = XGBRegressor(objective='reg:squarederror', n_estimators=200, max_depth=5, learning_rate=0.1, reg_alpha=0.1, reg_lambda=0.1)
    model.fit(X_train_flattened, y_train)

    # Make predictions
    predictions = model.predict(X_test_flattened)


    # Evaluate model
    mse = mean_squared_error(y_test, predictions)
    print(f'XGBoost Mean Squared Error: {mse}')

    # Plot predictions
    plt.plot(predictions, label='XGBoost Predicted')
    plt.plot(y_test, label='Actual')
    plt.legend()
    plt.show()


# Target variable: 'close'
target_variable = 'close'
target_data = df_standardized[[target_variable]]

scaler = MinMaxScaler()
target_data_scaled = scaler.fit_transform(target_data)

sequences = create_sequences(target_data_scaled, sequence_length)

train_size = int(len(sequences) * 0.8)
train_data, test_data = sequences[:train_size], sequences[train_size:]

X_train, y_train = train_data[:, :-1], train_data[:, -1]
X_test, y_test = test_data[:, :-1], test_data[:, -1]

# Train and evaluate XGBoost model for 'close'
train_evaluate_xgboost(X_train, y_train, X_test, y_test)
# Out:
# XGBoost Mean Squared Error: 0.0007050766304137685
